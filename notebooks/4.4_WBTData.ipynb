# %%
import xarray as xr

# %%
ds = xr.open_dataset('../data/processed/WBTdaily/WBTdailyens1.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:      (hist_interval: 2, lat: 192, lon: 288, time: 44166)
# Coordinates:
#   * lon          (lon) float32 0.0 1.25 2.5 3.75 ... 355.0 356.25 357.5 358.75
#   * lat          (lat) float32 -90.0 -89.057594 -88.11518 ... 89.057594 90.0
#   * time         (time) object 1980-01-01 10:30:00 ... 2100-12-31 22:30:00
# Dimensions without coordinates: hist_interval
# Data variables:
#     time_bounds  (time, hist_interval) object ...
#     WBT          (time, lat, lon) float32 ...
# Attributes:
#     title:                                     CLM History file information
#     comment:                                   NOTE: None of the variables ar...
#     Conventions:                               CF-1.0
#     history:                                   Tue Jun 16 18:03:21 2020: ncra...
#     source:                                    Community Land Model CLM4.0
#     hostname:                                  aleph
# ...
